# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

iris = sns.load_dataset("iris")
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.plot()
# Out:
# <Axes: >

# %%
iris.sepal_length.plot()
plt.savefig("sepallength.pdf")

# %%
#iris.plot.line()
#iris.plot.bar()
#iris.plot.barh()
#iris.plot.hist()
#iris.plot.box()
#iris.plot.density()
iris.plot.area()
# Out:
# <Axes: >

# %%
iris_group = iris.groupby("species")
virginica = iris_group.get_group("virginica")
virginica.plot.box()
# Out:
# <Axes: >

# %%
iris.plot.hexbin(x="sepal_length", y="sepal_width")
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
tips = sns.load_dataset("tips")

group_tips = tips.groupby("sex")

tip_stats = []
for grp, info in group_tips:
    tips_dict = {}
    
    avg_tip = round(info.tip.mean(), 2)
    avg_bill = round(info.total_bill.mean(), 2)
    
    tips_dict["Gender"] = grp
    tips_dict["Tips"] = avg_tip
    tips_dict["Total_Bill"] = avg_bill
    tips_dict["Tips_Percent"] = round(avg_tip / avg_bill * 100)
    tip_stats.append(tips_dict)

tip_df = pd.DataFrame(tip_stats)
tip_df
# Out:
# C:\Users\shmll\AppData\Local\Temp\ipykernel_27420\427523198.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   group_tips = tips.groupby("sex")
#    Gender  Tips  Total_Bill  Tips_Percent
# 0    Male  3.09       20.74            15
# 1  Female  2.83       18.06            16

# %%
tip_df.plot.pie(x="Gender", y="Tips_Percent")
labels = tip_df.Gender.unique()
plt.legend(labels)

# %%
# multiple plot method 1
plt.figure()                # prepare the space
plt.plot(iris.sepal_length)
plt.plot(iris.petal_length)

# %%
# multiple plot method 2
plt.figure()
plt.subplot(2, 1, 1)
plt.plot(iris.petal_length)
plt.subplot(2, 1, 2)
plt.plot(iris.sepal_length)

# %%
plt.figure()
plt.subplot(1, 2, 1)
plt.plot(iris.petal_length)
plt.subplot(1, 2, 2)
plt.plot(iris.sepal_length)

# %%
# multiple plot method 3
fig, ax = plt.subplots(2)
ax[0].plot(iris.petal_length)
ax[1].plot(iris.sepal_length)

# %%
# Labelling
plt.figure()
plt.plot(tips.tip)
plt.title("Tips from the Seaborn Tips Dataset")
plt.xlabel("Individual")
plt.ylabel("Tips")
# Out:
# Text(0, 0.5, 'Tips')

# %%
# Customisation
plt.figure()
plt.plot(tips.tip, '--g', label="Tips")
plt.plot(tips.total_bill, '-r', label="Total Bill")
plt.legend(loc="upper right")
plt.axis("equal")
# Out:
# (-12.15, 255.15, -1.4905000000000004, 53.3005)

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x="total_bill", y="tip", data=tips, hue="day", size="size", style="time")

# %%
sns.relplot(x="total_bill", y="tip", hue="time", col="smoker", data=tips)

# %%
sns.catplot(x="day", y="total_bill", kind="strip", data=tips)
# Out:
# C:\Users\shmll\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\shmll\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.catplot(x="day", y="total_bill", kind="violin", hue="time", palette="pastel", col="sex", data=tips)
# Out:
# C:\Users\shmll\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# C:\Users\shmll\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# C:\Users\shmll\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
