# %%
import pandas as pd

restaurant = pd.read_csv("restaurant_menu.csv")
restaurant.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   RestaurantID   1000 non-null   object
#  1   MenuCategory   1000 non-null   object
#  2   MenuItem       1000 non-null   object
#  3   Ingredients    1000 non-null   object
#  4   Price          1000 non-null   float64
#  5   Profitability  1000 non-null   object
# dtypes: float64(1), object(5)
# memory usage: 47.0+ KB

# %%
restaurant.describe()
# Out:
#             Price
# count  1000.00000
# mean     12.81801
# std       7.41713
# min       2.01000
# 25%       4.86750
# 50%      12.53500
# 75%      17.69000
# max      29.84000

# %%
restaurant
# Out:
#     RestaurantID MenuCategory               MenuItem  \
# 0           R003    Beverages                   Soda
# 1           R001   Appetizers  Spinach Artichoke Dip
# 2           R003     Desserts    New York Cheesecake
# 3           R003  Main Course        Chicken Alfredo
# 4           R002  Main Course          Grilled Steak
# ..           ...          ...                    ...
# 995         R003    Beverages                   Soda
# 996         R001   Appetizers          Caprese Salad
# 997         R003  Main Course     Vegetable Stir-Fry
# 998         R002     Desserts               Tiramisu
# 999         R001    Beverages                   Soda
#
#                                            Ingredients  Price Profitability
# 0                                     ['confidential']   2.55           Low
# 1         ['Tomatoes', 'Basil', 'Garlic', 'Olive Oil']  11.12        Medium
# 2             ['Chocolate', 'Butter', 'Sugar', 'Eggs']  18.66          High
# 3    ['Chicken', 'Fettuccine', 'Alfredo Sauce', 'Pa...  29.55          High
# 4    ['Chicken', 'Fettuccine', 'Alfredo Sauce', 'Pa...  17.73        Medium
# ..                                                 ...    ...           ...
# 995                                   ['confidential']   2.16           Low
# 996       ['Tomatoes', 'Basil', 'Garlic', 'Olive Oil']  11.86        Medium
# 997  ['Chicken', 'Fettuccine', 'Alfredo Sauce', 'Pa...  20.57          High
# 998           ['Chocolate', 'Butter', 'Sugar', 'Eggs']  18.80          High
# 999                                   ['confidential']   4.26        Medium
#
# [1000 rows x 6 columns]

# %%
grp_restaurant = restaurant.groupby("RestaurantID")

cat_list = []

for grp, grp_info in grp_restaurant:
    cat_dict = {}
    cat_dict["Restaurant"] = grp

    grp_res = grp_restaurant.get_group(grp)

    for index, row in grp_res.iterrows():
        if row["MenuCategory"] not in cat_dict.keys():
            cat_dict[row["MenuCategory"]] = [row["MenuItem"]]
        else:
            if row["MenuItem"] not in cat_dict.values():
                cat_dict[row["MenuCategory"]].append(row["MenuItem"])
    cat_list.append(cat_dict)

cat_list
# Out:
# [{'Restaurant': 'R001',
#   'Appetizers': ['Spinach Artichoke Dip',
#    'Stuffed Mushrooms',
#    'Spinach Artichoke Dip',
#    'Bruschetta',
#    'Spinach Artichoke Dip',
#    'Bruschetta',
#    'Stuffed Mushrooms',
#    'Caprese Salad',
#    'Stuffed Mushrooms',
#    'Spinach Artichoke Dip',
#    'Caprese Salad',
#    'Stuffed Mushrooms',
#    'Spinach Artichoke Dip',
#    'Caprese Salad',
#    'Caprese Salad',
#    'Stuffed Mushrooms',
#    'Stuffed Mushrooms',
#    'Bruschetta',
#    'Spinach Artichoke Dip',
#    'Stuffed Mushrooms',
#    'Stuffed Mushrooms',
#    'Caprese Salad',
#    'Spinach Artichoke Dip',
#    'Stuffed Mushrooms',
#    'Bruschetta',
#    'Stuffed Mushrooms',
#    'Caprese Salad',
#    'Bruschetta',
#    'Caprese Salad',
#    'Spinach Artichoke Dip',
#    'Stuffed Mushrooms',
#    'Bruschetta',
#    'Caprese Salad',
#    'Bruschetta',
#    'Bruschetta',
#    'Caprese Salad',
#    'Stuffed Mushrooms',
#    'Bruschetta',
#    'Caprese Salad',
#    'Spinach Artichoke Dip',
#    'Spinach Artichoke Dip',
#    'Spinach Artichoke Dip',
#    'Stuffed Mushrooms',
#    'Stuffed Mushrooms',
#    'Stuffed Mushrooms',
#    'Bruschetta',
#    'Stuffed Mushrooms',
#    'Spinach Artichoke Dip',
#    'Spinach Artichoke Dip',
#    'Caprese Salad',
#    'Bruschetta',
#    'Bruschetta',
#    'Bruschetta',
#    'Caprese Salad',
#    'Spinach Artichoke Dip',
#    'Caprese Salad',
#    'Stuffed Mushrooms',
#    'Stuffed Mushrooms',
#    'Spinach Artichoke Dip',
#    'Caprese Salad',
#    'Stuffed Mushrooms',
#    'Spinach Artichoke Dip',
#    'Bruschetta',
#    'Stuffed Mushrooms',
#    'Bruschetta',
#    'Bruschetta',
#    'Caprese Salad',
#    'Caprese Salad',
#    'Stuffed Mushrooms',
#    'Stuffed Mushrooms',
#    'Caprese Salad',
#    'Stuffed Mushrooms',
#    'Caprese Salad',
#    'Bruschetta',
#    'Caprese Salad',
#    'Stuffed Mushrooms',
#    'Stuffed Mushrooms',
#    'Spinach Artichoke Dip',
#    'Caprese Salad',
#    'Bruschetta',
#    'Spinach Artichoke Dip',
#    'Bruschetta',
#    'Stuffed Mushrooms',
#    'Caprese Salad',
#    'Bruschetta',
#    'Caprese Salad',
#    'Stuffed Mushrooms',
#    'Stuffed Mushrooms',
#    'Bruschetta',
#    'Spinach Artichoke Dip',
#    'Spinach Artichoke Dip',
#    'Bruschetta',
#    'Spinach Artichoke Dip',
#    'Caprese Salad',
#    'Stuffed Mushrooms',
#    'Stuffed Mushrooms',
#    'Caprese Salad'],
#   'Beverages': ['Soda',
#    'Iced Tea',
#    'Soda',
#    'Iced Tea',
#    'Coffee',
#    'Coffee',
#    'Soda',
#    'Soda',
#    'Soda',
#    'Coffee',
#    'Soda',
#    'Lemonade',
#    'Soda',
#    'Coffee',
#    'Soda',
#    'Soda',
#    'Coffee',
#    'Soda',
#    'Soda',
#    'Iced Tea',
#    'Lemonade',
#    'Soda',
#    'Lemonade',
#    'Lemonade',
#    'Iced Tea',
#    'Soda',
#    'Coffee',
#    'Lemonade',
#    'Soda',
#    'Soda',
#    'Soda',
#    'Soda',
#    'Iced Tea',
#    'Soda',
#    'Lemonade',
#    'Soda',
#    'Coffee',
#    'Soda',
#    'Coffee',
#    'Soda',
#    'Lemonade',
#    'Soda',
#    'Coffee',
#    'Iced Tea',
#    'Coffee',
#    'Iced Tea',
#    'Iced Tea',
#    'Coffee',
#    'Lemonade',
#    'Lemonade',
#    'Coffee',
#    'Lemonade',
#    'Coffee',
#    'Coffee',
#    'Coffee',
#    'Lemonade',
#    'Lemonade',
#    'Soda',
#    'Coffee',
#    'Coffee',
#    'Soda',
#    'Soda',
#    'Soda',
#    'Coffee',
#    'Iced Tea',
#    'Iced Tea',
#    'Iced Tea',
#    'Soda',
#    'Iced Tea',
#    'Soda',
#    'Lemonade',
#    'Coffee',
#    'Soda',
#    'Iced Tea',
#    'Coffee',
#    'Iced Tea',
#    'Lemonade',
#    'Soda',
#    'Coffee',
#    'Iced Tea',
#    'Iced Tea',
#    'Iced Tea',
#    'Lemonade',
#    'Iced Tea',
#    'Coffee',
#    'Coffee',
#    'Coffee',
#    'Lemonade',
#    'Lemonade',
#    'Lemonade',
#    'Lemonade',
#    'Lemonade',
#    'Lemonade',
#    'Soda'],
#   'Desserts': ['Chocolate Lava Cake',
#    'Tiramisu',
#    'New York Cheesecake',
#    'New York Cheesecake',
#    'Chocolate Lava Cake',
#    'Tiramisu',
#    'Fruit Tart',
#    'Fruit Tart',
#    'Fruit Tart',
#    'Fruit Tart',
#    'Chocolate Lava Cake',
#    'New York Cheesecake',
#    'Fruit Tart',
#    'Chocolate Lava Cake',
#    'New York Cheesecake',
#    'Chocolate Lava Cake',
#    'Fruit Tart',
#    'Fruit Tart',
#    'Chocolate Lava Cake',
#    'Chocolate Lava Cake',
#    'New York Cheesecake',
#    'Chocolate Lava Cake',
#    'New York Cheesecake',
#    'New York Cheesecake',
#    'New York Cheesecake',
#    'Fruit Tart',
#    'Fruit Tart',
#    'Tiramisu',
#    'Tiramisu',
#    'Fruit Tart',
#    'Tiramisu',
#    'New York Cheesecake',
#    'Chocolate Lava Cake',
#    'New York Cheesecake',
#    'New York Cheesecake',
#    'New York Cheesecake',
#    'Fruit Tart',
#    'Tiramisu',
#    'Chocolate Lava Cake',
#    'New York Cheesecake',
#    'Chocolate Lava Cake',
#    'Chocolate Lava Cake',
#    'Tiramisu',
#    'New York Cheesecake',
#    'Fruit Tart',
#    'Chocolate Lava Cake',
#    'New York Cheesecake',
#    'New York Cheesecake',
#    'Tiramisu',
#    'Tiramisu',
#    'Fruit Tart',
#    'New York Cheesecake',
#    'Tiramisu',
#    'Tiramisu',
#    'Tiramisu',
#    'Tiramisu',
#    'New York Cheesecake',
#    'Fruit Tart',
#    'Tiramisu',
#    'Chocolate Lava Cake',
#    'Tiramisu',
#    'Fruit Tart',
#    'Fruit Tart',
#    'Fruit Tart',
#    'New York Cheesecake',
#    'New York Cheesecake',
#    'Tiramisu',
#    'Fruit Tart',
#    'New York Cheesecake',
#    'Fruit Tart',
#    'Tiramisu',
#    'Tiramisu',
#    'Tiramisu',
#    'Chocolate Lava Cake',
#    'Fruit Tart',
#    'Tiramisu',
#    'Tiramisu',
#    'Fruit Tart',
#    'New York Cheesecake',
#    'Chocolate Lava Cake',
#    'Tiramisu',
#    'Fruit Tart',
#    'Fruit Tart',
#    'New York Cheesecake',
#    'Chocolate Lava Cake',
#    'Tiramisu',
#    'Chocolate Lava Cake',
#    'Fruit Tart'],
#   'Main Course': ['Chicken Alfredo',
#    'Vegetable Stir-Fry',
#    'Chicken Alfredo',
#    'Vegetable Stir-Fry',
#    'Shrimp Scampi',
#    'Chicken Alfredo',
#    'Chicken Alfredo',
#    'Shrimp Scampi',
#    'Shrimp Scampi',
#    'Grilled Steak',
#    'Chicken Alfredo',
#    'Grilled Steak',
#    'Grilled Steak',
#    'Shrimp Scampi',
#    'Vegetable Stir-Fry',
#    'Vegetable Stir-Fry',
#    'Grilled Steak',
#    'Shrimp Scampi',
#    'Vegetable Stir-Fry',
#    'Chicken Alfredo',
#    'Shrimp Scampi',
#    'Shrimp Scampi',
#    'Shrimp Scampi',
#    'Chicken Alfredo',
#    'Vegetable Stir-Fry',
#    'Vegetable Stir-Fry',
#    'Chicken Alfredo',
#    'Shrimp Scampi',
#    'Vegetable Stir-Fry',
#    'Chicken Alfredo',
#    'Grilled Steak',
#    'Chicken Alfredo',
#    'Shrimp Scampi',
#    'Vegetable Stir-Fry',
#    'Vegetable Stir-Fry',
#    'Vegetable Stir-Fry',
#    'Chicken Alfredo',
#    'Chicken Alfredo',
#    'Chicken Alfredo',
#    'Vegetable Stir-Fry',
#    'Vegetable Stir-Fry',
#    'Vegetable Stir-Fry',
#    'Shrimp Scampi',
#    'Shrimp Scampi',
#    'Chicken Alfredo',
#    'Shrimp Scampi',
#    'Shrimp Scampi',
#    'Shrimp Scampi',
#    'Vegetable Stir-Fry',
#    'Vegetable Stir-Fry',
#    'Grilled Steak',
#    'Grilled Steak',
#    'Vegetable Stir-Fry',
#    'Shrimp Scampi',
#    'Grilled Steak',
#    'Vegetable Stir-Fry',
#    'Grilled Steak',
#    'Chicken Alfredo',
#    'Grilled Steak',
#    'Vegetable Stir-Fry',
#    'Grilled Steak',
#    'Chicken Alfredo',
#    'Shrimp Scampi',
#    'Chicken Alfredo',
#    'Shrimp Scampi',
#    'Grilled Steak',
#    'Grilled Steak',
#    'Chicken Alfredo',
#    'Shrimp Scampi',
#    'Vegetable Stir-Fry',
#    'Chicken Alfredo',
#    'Shrimp Scampi',
#    'Chicken Alfredo',
#    'Vegetable Stir-Fry',
#    'Chicken Alfredo']},
#  {'Restaurant': 'R002',
#   'Main Course': ['Grilled Steak',
#    'Grilled Steak',
#    'Grilled Steak',
#    'Chicken Alfredo',
#    'Shrimp Scampi',
#    'Grilled Steak',
#    'Shrimp Scampi',
#    'Grilled Steak',
#    'Grilled Steak',
#    'Vegetable Stir-Fry',
#    'Grilled Steak',
#    'Vegetable Stir-Fry',
#    'Shrimp Scampi',
#    'Shrimp Scampi',
#    'Shrimp Scampi',
#    'Grilled Steak',
#    'Grilled Steak',
#    'Chicken Alfredo',
#    'Grilled Steak',
#    'Grilled Steak',
#    'Grilled Steak',
#    'Chicken Alfredo',
#    'Vegetable Stir-Fry',
#    'Grilled Steak',
#    'Chicken Alfredo',
#    'Vegetable Stir-Fry',
#    'Shrimp Scampi',
#    'Vegetable Stir-Fry',
#    'Chicken Alfredo',
#    'Vegetable Stir-Fry',
#    'Vegetable Stir-Fry',
#    'Shrimp Scampi',
#    'Chicken Alfredo',
#    'Grilled Steak',
#    'Grilled Steak',
#    'Vegetable Stir-Fry',
#    'Grilled Steak',
#    'Vegetable Stir-Fry',
#    'Vegetable Stir-Fry',
#    'Shrimp Scampi',
#    'Grilled Steak',
#    'Shrimp Scampi',
#    'Shrimp Scampi',
#    'Chicken Alfredo',
#    'Vegetable Stir-Fry',
#    'Chicken Alfredo',
#    'Vegetable Stir-Fry',
#    'Vegetable Stir-Fry',
#    'Grilled Steak',
#    'Shrimp Scampi',
#    'Chicken Alfredo',
#    'Vegetable Stir-Fry',
#    'Grilled Steak',
#    'Chicken Alfredo',
#    'Grilled Steak',
#    'Grilled Steak',
#    'Vegetable Stir-Fry',
#    'Vegetable Stir-Fry',
#    'Shrimp Scampi',
#    'Chicken Alfredo',
#    'Vegetable Stir-Fry',
#    'Chicken Alfredo',
#    'Vegetable Stir-Fry',
#    'Grilled Steak',
#    'Grilled Steak',
#    'Shrimp Scampi',
#    'Vegetable Stir-Fry',
#    'Vegetable Stir-Fry',
#    'Vegetable Stir-Fry',
#    'Shrimp Scampi',
#    'Shrimp Scampi',
#    'Grilled Steak',
#    'Grilled Steak',
#    'Chicken Alfredo',
#    'Vegetable Stir-Fry',
#    'Grilled Steak',
#    'Vegetable Stir-Fry',
#    'Vegetable Stir-Fry',
#    'Grilled Steak',
#    'Grilled Steak',
#    'Vegetable Stir-Fry',
#    'Vegetable Stir-Fry'],
#   'Beverages': ['Coffee',
#    'Coffee',
#    'Iced Tea',
#    'Soda',
#    'Coffee',
#    'Iced Tea',
#    'Iced Tea',
#    'Lemonade',
#    'Lemonade',
#    'Coffee',
#    'Soda',
#    'Iced Tea',
#    'Coffee',
#    'Coffee',
#    'Iced Tea',
#    'Lemonade',
#    'Soda',
#    'Soda',
#    'Soda',
#    'Lemonade',
#    'Iced Tea',
#    'Iced Tea',
#    'Iced Tea',
#    'Soda',
#    'Iced Tea',
#    'Lemonade',
#    'Soda',
#    'Soda',
#    'Coffee',
#    'Coffee',
#    'Lemonade',
#    'Soda',
#    'Lemonade',
#    'Lemonade',
#    'Lemonade',
#    'Soda',
#    'Coffee',
#    'Lemonade',
#    'Coffee',
#    'Iced Tea',
#    'Iced Tea',
#    'Coffee',
#    'Soda',
#    'Coffee',
#    'Coffee',
#    'Lemonade',
#    'Lemonade',
#    'Iced Tea',
#    'Iced Tea',
#    'Soda',
#    'Lemonade',
#    'Iced Tea',
#    'Lemonade',
#    'Soda',
#    'Soda',
#    'Coffee',
#    'Coffee',
#    'Lemonade',
#    'Coffee',
#    'Iced Tea',
#    'Iced Tea',
#    'Coffee',
#    'Iced Tea',
#    'Soda',
#    'Lemonade',
#    'Iced Tea',
#    'Lemonade',
#    'Lemonade',
#    'Iced Tea',
#    'Soda',
#    'Iced Tea',
#    'Soda',
#    'Soda',
#    'Iced Tea',
#    'Iced Tea',
#    'Iced Tea',
#    'Coffee',
#    'Lemonade'],
#   'Desserts': ['Chocolate Lava Cake',
#    'Chocolate Lava Cake',
#    'Chocolate Lava Cake',
#    'Fruit Tart',
#    'Tiramisu',
#    'Chocolate Lava Cake',
#    'Chocolate Lava Cake',
#    'New York Cheesecake',
#    'Tiramisu',
#    'Tiramisu',
#    'Tiramisu',
#    'New York Cheesecake',
#    'Chocolate Lava Cake',
#    'New York Cheesecake',
#    'New York Cheesecake',
#    'New York Cheesecake',
#    'Chocolate Lava Cake',
#    'Chocolate Lava Cake',
#    'Fruit Tart',
#    'Chocolate Lava Cake',
#    'New York Cheesecake',
#    'New York Cheesecake',
#    'New York Cheesecake',
#    'Fruit Tart',
#    'Chocolate Lava Cake',
#    'New York Cheesecake',
#    'Tiramisu',
#    'Tiramisu',
#    'Fruit Tart',
#    'Chocolate Lava Cake',
#    'Tiramisu',
#    'New York Cheesecake',
#    'Tiramisu',
#    'Fruit Tart',
#    'New York Cheesecake',
#    'Chocolate Lava Cake',
#    'Fruit Tart',
#    'New York Cheesecake',
#    'Tiramisu',
#    'Tiramisu',
#    'Tiramisu',
#    'Chocolate Lava Cake',
#    'Tiramisu',
#    'Tiramisu',
#    'Tiramisu',
#    'Chocolate Lava Cake',
#    'Tiramisu',
#    'Tiramisu',
#    'Chocolate Lava Cake',
#    'Tiramisu',
#    'Fruit Tart',
#    'Fruit Tart',
#    'Tiramisu',
#    'Tiramisu',
#    'New York Cheesecake',
#    'Tiramisu',
#    'Tiramisu',
#    'Tiramisu',
#    'Chocolate Lava Cake',
#    'New York Cheesecake',
#    'New York Cheesecake',
#    'New York Cheesecake',
#    'Tiramisu',
#    'New York Cheesecake',
#    'Tiramisu',
#    'Fruit Tart',
#    'Fruit Tart',
#    'Fruit Tart',
#    'Fruit Tart',
#    'Fruit Tart',
#    'New York Cheesecake',
#    'Chocolate Lava Cake',
#    'New York Cheesecake',
#    'Fruit Tart',
#    'Chocolate Lava Cake',
#    'New York Cheesecake',
#    'Fruit Tart',
#    'New York Cheesecake',
#    'Tiramisu',
#    'Tiramisu',
#    'New York Cheesecake',
#    'Chocolate Lava Cake',
#    'Tiramisu',
#    'New York Cheesecake',
#    'New York Cheesecake',
#    'Tiramisu'],
#   'Appetizers': ['Spinach Artichoke Dip',
#    'Bruschetta',
#    'Spinach Artichoke Dip',
#    'Caprese Salad',
#    'Caprese Salad',
#    'Caprese Salad',
#    'Stuffed Mushrooms',
#    'Spinach Artichoke Dip',
#    'Spinach Artichoke Dip',
#    'Stuffed Mushrooms',
#    'Spinach Artichoke Dip',
#    'Bruschetta',
#    'Spinach Artichoke Dip',
#    'Caprese Salad',
#    'Bruschetta',
#    'Spinach Artichoke Dip',
#    'Caprese Salad',
#    'Caprese Salad',
#    'Caprese Salad',
#    'Caprese Salad',
#    'Bruschetta',
#    'Caprese Salad',
#    'Stuffed Mushrooms',
#    'Bruschetta',
#    'Stuffed Mushrooms',
#    'Bruschetta',
#    'Bruschetta',
#    'Stuffed Mushrooms',
#    'Bruschetta',
#    'Bruschetta',
#    'Spinach Artichoke Dip',
#    'Spinach Artichoke Dip',
#    'Stuffed Mushrooms',
#    'Bruschetta',
#    'Spinach Artichoke Dip',
#    'Bruschetta',
#    'Stuffed Mushrooms',
#    'Bruschetta',
#    'Caprese Salad',
#    'Stuffed Mushrooms',
#    'Bruschetta',
#    'Caprese Salad',
#    'Stuffed Mushrooms',
#    'Bruschetta',
#    'Caprese Salad',
#    'Bruschetta',
#    'Caprese Salad',
#    'Caprese Salad',
#    'Bruschetta',
#    'Spinach Artichoke Dip',
#    'Caprese Salad',
#    'Caprese Salad',
#    'Stuffed Mushrooms',
#    'Bruschetta',
#    'Bruschetta',
#    'Bruschetta',
#    'Caprese Salad',
#    'Caprese Salad',
#    'Spinach Artichoke Dip',
#    'Caprese Salad',
#    'Spinach Artichoke Dip',
#    'Bruschetta',
#    'Bruschetta',
#    'Stuffed Mushrooms',
#    'Bruschetta',
#    'Bruschetta',
#    'Bruschetta',
#    'Stuffed Mushrooms',
#    'Bruschetta',
#    'Caprese Salad',
#    'Spinach Artichoke Dip',
#    'Caprese Salad',
#    'Bruschetta',
#    'Caprese Salad',
#    'Caprese Salad',
#    'Stuffed Mushrooms',
#    'Bruschetta',
#    'Spinach Artichoke Dip',
#    'Bruschetta']},
#  {'Restaurant': 'R003',
#   'Beverages': ['Soda',
#    'Lemonade',
#    'Lemonade',
#    'Lemonade',
#    'Soda',
#    'Coffee',
#    'Soda',
#    'Soda',
#    'Coffee',
#    'Soda',
#    'Soda',
#    'Soda',
#    'Iced Tea',
#    'Coffee',
#    'Soda',
#    'Iced Tea',
#    'Coffee',
#    'Soda',
#    'Soda',
#    'Lemonade',
#    'Iced Tea',
#    'Lemonade',
#    'Soda',
#    'Lemonade',
#    'Coffee',
#    'Soda',
#    'Lemonade',
#    'Iced Tea',
#    'Coffee',
#    'Coffee',
#    'Iced Tea',
#    'Coffee',
#    'Lemonade',
#    'Iced Tea',
#    'Iced Tea',
#    'Coffee',
#    'Coffee',
#    'Lemonade',
#    'Lemonade',
#    'Lemonade',
#    'Iced Tea',
#    'Soda',
#    'Coffee',
#    'Iced Tea',
#    'Iced Tea',
#    'Iced Tea',
#    'Coffee',
#    'Iced Tea',
#    'Coffee',
#    'Iced Tea',
#    'Soda',
#    'Lemonade',
#    'Soda',
#    'Iced Tea',
#    'Soda',
#    'Iced Tea',
#    'Iced Tea',
#    'Coffee',
#    'Iced Tea',
#    'Iced Tea',
#    'Iced Tea',
#    'Iced Tea',
#    'Iced Tea',
#    'Lemonade',
#    'Coffee',
#    'Iced Tea',
#    'Coffee',
#    'Coffee',
#    'Soda',
#    'Iced Tea',
#    'Iced Tea',
#    'Lemonade',
#    'Iced Tea',
#    'Iced Tea',
#    'Coffee',
#    'Lemonade',
#    'Coffee',
#    'Coffee',
#    'Coffee',
#    'Iced Tea',
#    'Coffee',
#    'Iced Tea',
#    'Coffee',
#    'Soda',
#    'Lemonade',
#    'Iced Tea',
#    'Lemonade',
#    'Iced Tea',
#    'Soda',
#    'Coffee',
#    'Iced Tea',
#    'Soda'],
#   'Desserts': ['New York Cheesecake',
#    'Tiramisu',
#    'Tiramisu',
#    'Chocolate Lava Cake',
#    'Tiramisu',
#    'Tiramisu',
#    'Chocolate Lava Cake',
#    'New York Cheesecake',
#    'Tiramisu',
#    'Fruit Tart',
#    'Chocolate Lava Cake',
#    'Tiramisu',
#    'Chocolate Lava Cake',
#    'Chocolate Lava Cake',
#    'Tiramisu',
#    'Chocolate Lava Cake',
#    'New York Cheesecake',
#    'New York Cheesecake',
#    'Chocolate Lava Cake',
#    'Fruit Tart',
#    'New York Cheesecake',
#    'Tiramisu',
#    'New York Cheesecake',
#    'New York Cheesecake',
#    'Chocolate Lava Cake',
#    'Chocolate Lava Cake',
#    'Fruit Tart',
#    'New York Cheesecake',
#    'Fruit Tart',
#    'Fruit Tart',
#    'Fruit Tart',
#    'Fruit Tart',
#    'Tiramisu',
#    'Chocolate Lava Cake',
#    'New York Cheesecake',
#    'Fruit Tart',
#    'Fruit Tart',
#    'Tiramisu',
#    'Tiramisu',
#    'Fruit Tart',
#    'Fruit Tart',
#    'New York Cheesecake',
#    'Tiramisu',
#    'Chocolate Lava Cake',
#    'Fruit Tart',
#    'New York Cheesecake',
#    'Chocolate Lava Cake',
#    'Chocolate Lava Cake',
#    'Chocolate Lava Cake',
#    'Tiramisu',
#    'Fruit Tart',
#    'Chocolate Lava Cake',
#    'Fruit Tart',
#    'New York Cheesecake',
#    'New York Cheesecake',
#    'Chocolate Lava Cake',
#    'New York Cheesecake',
#    'Fruit Tart',
#    'New York Cheesecake',
#    'Tiramisu',
#    'Tiramisu',
#    'New York Cheesecake',
#    'Fruit Tart',
#    'New York Cheesecake',
#    'Tiramisu',
#    'Tiramisu',
#    'Fruit Tart',
#    'New York Cheesecake',
#    'Fruit Tart',
#    'New York Cheesecake',
#    'Fruit Tart',
#    'New York Cheesecake',
#    'New York Cheesecake',
#    'Tiramisu',
#    'New York Cheesecake',
#    'New York Cheesecake',
#    'Tiramisu',
#    'Fruit Tart',
#    'New York Cheesecake',
#    'Chocolate Lava Cake',
#    'Fruit Tart',
#    'Chocolate Lava Cake'],
#   'Main Course': ['Chicken Alfredo',
#    'Grilled Steak',
#    'Chicken Alfredo',
#    'Vegetable Stir-Fry',
#    'Vegetable Stir-Fry',
#    'Shrimp Scampi',
#    'Vegetable Stir-Fry',
#    'Vegetable Stir-Fry',
#    'Grilled Steak',
#    'Chicken Alfredo',
#    'Shrimp Scampi',
#    'Vegetable Stir-Fry',
#    'Grilled Steak',
#    'Chicken Alfredo',
#    'Vegetable Stir-Fry',
#    'Shrimp Scampi',
#    'Shrimp Scampi',
#    'Shrimp Scampi',
#    'Chicken Alfredo',
#    'Grilled Steak',
#    'Grilled Steak',
#    'Grilled Steak',
#    'Shrimp Scampi',
#    'Chicken Alfredo',
#    'Chicken Alfredo',
#    'Chicken Alfredo',
#    'Vegetable Stir-Fry',
#    'Chicken Alfredo',
#    'Shrimp Scampi',
#    'Chicken Alfredo',
#    'Vegetable Stir-Fry',
#    'Chicken Alfredo',
#    'Grilled Steak',
#    'Vegetable Stir-Fry',
#    'Shrimp Scampi',
#    'Grilled Steak',
#    'Grilled Steak',
#    'Chicken Alfredo',
#    'Shrimp Scampi',
#    'Shrimp Scampi',
#    'Vegetable Stir-Fry',
#    'Shrimp Scampi',
#    'Shrimp Scampi',
#    'Grilled Steak',
#    'Chicken Alfredo',
#    'Chicken Alfredo',
#    'Chicken Alfredo',
#    'Vegetable Stir-Fry',
#    'Grilled Steak',
#    'Grilled Steak',
#    'Shrimp Scampi',
#    'Vegetable Stir-Fry',
#    'Vegetable Stir-Fry',
#    'Vegetable Stir-Fry',
#    'Shrimp Scampi',
#    'Vegetable Stir-Fry',
#    'Shrimp Scampi',
#    'Shrimp Scampi',
#    'Vegetable Stir-Fry',
#    'Shrimp Scampi',
#    'Shrimp Scampi',
#    'Shrimp Scampi',
#    'Grilled Steak',
#    'Vegetable Stir-Fry',
#    'Shrimp Scampi',
#    'Chicken Alfredo',
#    'Vegetable Stir-Fry',
#    'Grilled Steak',
#    'Vegetable Stir-Fry'],
#   'Appetizers': ['Spinach Artichoke Dip',
#    'Spinach Artichoke Dip',
#    'Caprese Salad',
#    'Stuffed Mushrooms',
#    'Caprese Salad',
#    'Caprese Salad',
#    'Spinach Artichoke Dip',
#    'Spinach Artichoke Dip',
#    'Caprese Salad',
#    'Stuffed Mushrooms',
#    'Stuffed Mushrooms',
#    'Caprese Salad',
#    'Spinach Artichoke Dip',
#    'Bruschetta',
#    'Bruschetta',
#    'Bruschetta',
#    'Caprese Salad',
#    'Caprese Salad',
#    'Spinach Artichoke Dip',
#    'Bruschetta',
#    'Stuffed Mushrooms',
#    'Stuffed Mushrooms',
#    'Spinach Artichoke Dip',
#    'Caprese Salad',
#    'Spinach Artichoke Dip',
#    'Caprese Salad',
#    'Caprese Salad',
#    'Spinach Artichoke Dip',
#    'Caprese Salad',
#    'Bruschetta',
#    'Caprese Salad',
#    'Spinach Artichoke Dip',
#    'Spinach Artichoke Dip',
#    'Caprese Salad',
#    'Stuffed Mushrooms',
#    'Spinach Artichoke Dip',
#    'Stuffed Mushrooms',
#    'Spinach Artichoke Dip',
#    'Caprese Salad',
#    'Spinach Artichoke Dip',
#    'Bruschetta',
#    'Bruschetta',
#    'Stuffed Mushrooms',
#    'Stuffed Mushrooms',
#    'Stuffed Mushrooms',
#    'Stuffed Mushrooms',
#    'Bruschetta',
#    'Caprese Salad',
#    'Caprese Salad',
#    'Caprese Salad',
#    'Stuffed Mushrooms',
#    'Caprese Salad',
#    'Spinach Artichoke Dip',
#    'Spinach Artichoke Dip',
#    'Bruschetta',
#    'Spinach Artichoke Dip',
#    'Spinach Artichoke Dip',
#    'Spinach Artichoke Dip',
#    'Spinach Artichoke Dip',
#    'Stuffed Mushrooms',
#    'Spinach Artichoke Dip',
#    'Bruschetta',
#    'Spinach Artichoke Dip',
#    'Bruschetta',
#    'Caprese Salad',
#    'Spinach Artichoke Dip',
#    'Spinach Artichoke Dip',
#    'Spinach Artichoke Dip',
#    'Spinach Artichoke Dip',
#    'Bruschetta',
#    'Spinach Artichoke Dip',
#    'Stuffed Mushrooms',
#    'Stuffed Mushrooms',
#    'Spinach Artichoke Dip',
#    'Caprese Salad',
#    'Stuffed Mushrooms',
#    'Bruschetta',
#    'Bruschetta']}]

# %%
for row in cat_list:
    for key, value in row.items():
        item = {}
        if isinstance(value, list):
            for v in value:
                if v not in item.keys():
                    item[v] = 1
                else:
                    item[v] += 1
            row[key] = item

cat_list
# Out:
# [{'Restaurant': 'R001',
#   'Appetizers': {'Spinach Artichoke Dip': 21,
#    'Stuffed Mushrooms': 30,
#    'Bruschetta': 22,
#    'Caprese Salad': 24},
#   'Beverages': {'Soda': 31, 'Iced Tea': 18, 'Coffee': 24, 'Lemonade': 21},
#   'Desserts': {'Chocolate Lava Cake': 18,
#    'Tiramisu': 23,
#    'New York Cheesecake': 23,
#    'Fruit Tart': 24},
#   'Main Course': {'Chicken Alfredo': 21,
#    'Vegetable Stir-Fry': 21,
#    'Shrimp Scampi': 20,
#    'Grilled Steak': 13}},
#  {'Restaurant': 'R002',
#   'Main Course': {'Grilled Steak': 28,
#    'Chicken Alfredo': 13,
#    'Shrimp Scampi': 15,
#    'Vegetable Stir-Fry': 26},
#   'Beverages': {'Coffee': 18, 'Iced Tea': 23, 'Soda': 18, 'Lemonade': 19},
#   'Desserts': {'Chocolate Lava Cake': 19,
#    'Fruit Tart': 15,
#    'Tiramisu': 28,
#    'New York Cheesecake': 24},
#   'Appetizers': {'Spinach Artichoke Dip': 15,
#    'Bruschetta': 28,
#    'Caprese Salad': 23,
#    'Stuffed Mushrooms': 13}},
#  {'Restaurant': 'R003',
#   'Beverages': {'Soda': 20, 'Lemonade': 17, 'Coffee': 24, 'Iced Tea': 31},
#   'Desserts': {'New York Cheesecake': 24,
#    'Tiramisu': 19,
#    'Chocolate Lava Cake': 18,
#    'Fruit Tart': 21},
#   'Main Course': {'Chicken Alfredo': 16,
#    'Grilled Steak': 14,
#    'Vegetable Stir-Fry': 19,
#    'Shrimp Scampi': 20},
#   'Appetizers': {'Spinach Artichoke Dip': 28,
#    'Caprese Salad': 20,
#    'Stuffed Mushrooms': 16,
#    'Bruschetta': 14}}]

# %%
grp_restaurant = restaurant.groupby("RestaurantID")

cat_list = []

for grp, grp_info in grp_restaurant:
    cat_dict = {}
    cat_dict["Restaurant"] = grp

    grp_res = grp_restaurant.get_group(grp)

    for index, row in grp_res.iterrows():
        if row["MenuCategory"] not in cat_dict.keys():
            cat_dict[row["MenuCategory"]] = [row["Price"]]
        else:
            cat_dict[row["MenuCategory"]].append(row["Price"])
    cat_list.append(cat_dict)

cat_list
# Out:
# [{'Restaurant': 'R001',
#   'Appetizers': [11.12,
#    12.28,
#    8.09,
#    13.62,
#    10.96,
#    12.53,
#    11.56,
#    14.47,
#    12.43,
#    12.9,
#    14.77,
#    13.96,
#    12.96,
#    14.41,
#    8.64,
#    14.34,
#    8.71,
#    9.97,
#    8.64,
#    10.45,
#    14.9,
#    8.53,
#    13.25,
#    12.33,
#    10.49,
#    11.32,
#    9.58,
#    12.17,
#    13.22,
#    12.66,
#    10.9,
#    9.23,
#    10.83,
#    10.46,
#    12.82,
#    12.83,
#    8.13,
#    8.81,
#    14.56,
#    11.69,
#    9.55,
#    10.94,
#    10.58,
#    11.25,
#    13.46,
#    9.74,
#    13.64,
#    9.57,
#    10.21,
#    10.44,
#    14.95,
#    11.97,
#    11.82,
#    8.76,
#    11.02,
#    8.99,
#    9.34,
#    8.47,
#    13.28,
#    11.65,
#    11.55,
#    9.55,
#    8.08,
#    11.41,
#    8.72,
#    13.66,
#    14.51,
#    12.67,
#    10.29,
#    10.82,
#    12.45,
#    10.21,
#    14.86,
#    8.15,
#    10.83,
#    14.43,
#    11.46,
#    8.99,
#    10.38,
#    8.23,
#    9.66,
#    13.73,
#    12.72,
#    14.69,
#    12.25,
#    9.18,
#    14.35,
#    9.93,
#    14.25,
#    12.39,
#    9.0,
#    9.53,
#    10.5,
#    9.31,
#    13.33,
#    13.47,
#    11.86],
#   'Beverages': [2.87,
#    4.43,
#    2.81,
#    4.9,
#    2.02,
#    14.08,
#    11.78,
#    9.67,
#    13.48,
#    13.39,
#    12.52,
#    14.92,
#    8.29,
#    12.31,
#    13.2,
#    13.2,
#    10.58,
#    10.6,
#    10.1,
#    13.82,
#    9.82,
#    12.95,
#    11.92,
#    10.66,
#    9.37,
#    9.37,
#    14.28,
#    13.59,
#    8.86,
#    8.65,
#    12.35,
#    10.86,
#    14.15,
#    14.1,
#    8.31,
#    11.8,
#    8.69,
#    12.74,
#    11.41,
#    12.08,
#    8.28,
#    9.4,
#    8.54,
#    10.82,
#    12.81,
#    14.13]}]

# %%
for row in cat_list:
    for key, value in row.items():
        item = {}
        if isinstance(value, list):
            item["Min"] = min(value)
            item["Mean"] = round((sum(value) / len(value)), 2)
            item["Max"] = max(value)
            row[key] = item

cat_list
# Out:
# [{'Restaurant': 'R001',
#   'Appetizers': {'Min': 8.08, 'Mean': 11.407731958762888, 'Max': 14.95},
#   'Beverages': {'Min': 2.01, 'Mean': 3.524893617021276, 'Max': 4.99},
#   'Desserts': {'Min': 10.01, 'Mean': 15.31602272727274, 'Max': 19.86},
#   'Main Course': {'Min': 15.11, 'Mean': 22.446, 'Max': 29.45}},
#  {'Restaurant': 'R002',
#   'Main Course': {'Min': 15.09, 'Mean': 22.690609756097565, 'Max': 29.78},
#   'Beverages': {'Min': 2.01, 'Mean': 3.3579487179487173, 'Max': 4.87},
#   'Desserts': {'Min': 10.01, 'Mean': 14.587209302325581, 'Max': 19.96},
#   'Appetizers': {'Min': 8.24, 'Mean': 11.111772151898732, 'Max': 14.82}},
#  {'Restaurant': 'R003',
#   'Beverages': {'Min': 2.04, 'Mean': 3.6108695652173926, 'Max': 4.98},
#   'Desserts': {'Min': 10.09, 'Mean': 15.006829268292686, 'Max': 19.9},
#   'Main Course': {'Min': 15.35, 'Mean': 23.401449275362324, 'Max': 29.84},
#   'Appetizers': {'Min': 8.28, 'Mean': 11.750256410256412, 'Max': 14.92}}]

# %%
ing_list = []

for grp, grp_info in grp_restaurant:
    ing_dict = {}
    ing_dict["Restaurant"] = grp

    res_grp = grp_restaurant.get_group(grp)

    for index, row in res_grp.iterrows():
        temp = row["Ingredients"].replace("[", "").replace("]", "").replace("'", "")
        temptemp = temp.split(", ") # to convert to list
        
        for t in temptemp:
            if t not in ing_dict.keys():
                ing_dict[t] = 1
            else:
                ing_dict[t] += 1
    del ing_dict['confidential']
    ing_list.append(ing_dict)

ing_df = pd.DataFrame(ing_list)
ing_df
# Out:
#   Restaurant  Tomatoes  Basil  Garlic  Olive Oil  Chocolate  Butter  Sugar  \
# 0       R001        97     97      97         97         88      88     88
# 1       R002        79     79      79         79         86      86     86
# 2       R003        78     78      78         78         82      82     82
#
#    Eggs  Chicken  Fettuccine  Alfredo Sauce  Parmesan
# 0    88       75          75             75        75
# 1    86       82          82             82        82
# 2    82       69          69             69        69

# %%
# Out:
# ['Tomatoes',
#  'Basil',
#  'Garlic',
#  'Olive Oil',
#  'Tomatoes',
#  'Basil',
#  'Garlic',
#  'Olive Oil']
